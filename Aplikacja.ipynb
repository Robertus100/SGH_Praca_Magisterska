# %%
from PIL import Image
logo = Image.open("logo.png")
logo = logo.resize((160,160),Image.ANTIALIAS)
logo
# Out:
# <PIL.Image.Image image mode=RGBA size=160x160 at 0x10EE37E10>

# %% [markdown]
# # SYSTEM WSPOMAGAJĄCY ZARZĄDZANIE INTERWENCJAMI POLICJI

# %% [markdown]
# ### Wprowadź dane. Zatwierdź je przy pomocy klawiszy SHIFT+ENTER

# %% [markdown]
# Numer komendy policji (w formacie 0XX, np. 001 lub 011)

# %%
komenda='001'

# %% [markdown]
# ### Dzień tygodnia

# %% [markdown]
# Do wyboru: 'Poniedzialek', 'Wtorek', 'Sroda', 'Czwartek', 'Piatek', 'Sobota', 'Niedziela'

# %% [markdown]
# * Brak polskich znaków!

# %% [markdown]
# * Należy wybrać wyłącznie jeden dzień!

# %%
dzien_tygodnia=['Niedziela']

# %% [markdown]
# ### Miesiąc w formacie liczbowym

# %%
miesiac=9

# %% [markdown]
# ### Godzina rozpoczęcia zmiany

# %%
godzina_rozpoczecia=18

# %% [markdown]
# ### Godzina zakończenia zmiany

# %%
godzina_zakonczenia=22

# %% [markdown]
# ### Liczba dostępnych patroli

# %% [markdown]
# * Maksymalnie 9.

# %%
liczba_patroli=4

# %% [markdown]
# ### Typ przestępstw, na których prewencji należy się skupić podczas danej zmiany

# %% [markdown]
#  Do wyboru:<br> 'PODPALENIE','ATAK','POBICIE','WLAMANIE','NOSZENIE BRONI W MIEJSCU PUBLICZNYM','NAPASC NA TLE SEKSUALNYM','USZKODZENIE MIENIA','BEZPRAWNE WTARGNIECIE','WPROWADZAJACE W BLAD PRAKTYKI','HAZARD','ZABOJSTWO','HANDEL LUDZMI','ZNIEWAGA FUNKCJONARIUSZA PUBLICZNEGO','ZASTRASZENIE','PORWANIE','NARUSZENIE WARUNKOW SPRZEDAZY ALKOHOLU','KRADZIEZ POJAZDU','NARKOTYKI','NIE - KRYMINALNE','NIE-KRYMINALNE','NIE-KRYMINALNE (PRZEDMIOT WSKAZANY)','OBSCENICZNOSC','WYKROCZENIE Z UDZIALEM DZIECI','INNE Z UDZIALEM NARKOTYKOW','INNY ATAK','PROSTYTUCJA','PUBLICZNE OBNAZANIE SIE','ZAKLOCANIE SPOKOJU PUBLICZNEGO','NAPAD','MOLESTOWANIE','PRZESLADOWANIE','KRADZIEZ','NIELEGALNE POSIADANIE BRONI'

# %% [markdown]
# * Brak polskich znaków!

# %% [markdown]
# * Można wybrać dowolną licznę przestępstw!

# %%
typ_przestepstwa=['PODPALENIE','ATAK','POBICIE','WLAMANIE','NOSZENIE BRONI W MIEJSCU PUBLICZNYM','NAPASC NA TLE SEKSUALNYM','USZKODZENIE MIENIA','BEZPRAWNE WTARGNIECIE','WPROWADZAJACE W BLAD PRAKTYKI','HAZARD','ZABOJSTWO','HANDEL LUDZMI','ZNIEWAGA FUNKCJONARIUSZA PUBLICZNEGO','ZASTRASZENIE','PORWANIE','NARUSZENIE WARUNKOW SPRZEDAZY ALKOHOLU','KRADZIEZ POJAZDU','NARKOTYKI','NIE - KRYMINALNE','NIE-KRYMINALNE','NIE-KRYMINALNE (PRZEDMIOT WSKAZANY)','OBSCENICZNOSC','WYKROCZENIE Z UDZIALEM DZIECI','INNE Z UDZIALEM NARKOTYKOW','INNY ATAK','PROSTYTUCJA','PUBLICZNE OBNAZANIE SIE','ZAKLOCANIE SPOKOJU PUBLICZNEGO','NAPAD','MOLESTOWANIE','PRZESLADOWANIE','KRADZIEZ','NIELEGALNE POSIADANIE BRONI']

# %% [markdown]
# ### Zatwierdź poniższy kod klawiszami SHIFT+ENTER w celu wygenerowania mapy

# %%
import app
app.pokaz_mape(komenda, liczba_patroli, dzien_tygodnia, miesiac, typ_przestepstwa, godzina_rozpoczecia, godzina_zakonczenia)
# Out:
# /Users/ewagerus/Documents/SGH/magisterka/praca_magisterska/2.1/app.py:80: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   punkty = df[['latitude', 'longitude']].as_matrix()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
app.pokaz_tabele(komenda, liczba_patroli, dzien_tygodnia, miesiac, typ_przestepstwa, godzina_rozpoczecia, godzina_zakonczenia)
# Out:
#     Latitude  Longitude      kolor
# 0  41.883569 -87.626454   czerwony
# 1  41.843479 -87.620852    zielony
# 2  41.867216 -87.626948  niebieski
# 3  41.872379 -87.640343      zolty
